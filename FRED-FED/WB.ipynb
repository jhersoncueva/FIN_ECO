# %%
import pandas as pd
import tradingeconomics as te
te.login('guest:guest')

## Without a client key only a small sample of data will be given.

## Putting country name or indicator name in square brackets [] will result, by default
## in the dictionary type for several countries and indicators.
## EXE: country=['mexico', 'sweden']

## With no output_type defined, the result will be of the dictionary type.
## Use output_type='df' to display in pandas dataframe.

# To list World Bank main categories
mydata = te.getWBCategories(category=None, output_type='df')
print(mydata)
print("===============================================================================================================")

# To list by the main categories
mydata = te.getWBCategories(category='Demographics', output_type='df')
print(mydata)
print("===============================================================================================================")

# To ger getailed information about specific indicator for all countries using a series code from the previous method
mydata = te.getWBIndicator(series_code='SE.ADT.1524.LT.FE.ZS', output_type='df')
print(mydata)
print("===============================================================================================================")

# To tist the indicators available for a specific country
mydata = te.getWBCountry(country='Portugal', output_type='df')
print(mydata)
print("===============================================================================================================")

# To get detailed information just for a specific indicator and country by using series code or url
mydata = te.getWBIndicator(series_code='usa.fr.inr.rinr', output_type='df')

mydata = te.getWBIndicator(url='/united-states/real-interest-rate-percent-wb-data.html', output_type='df')
print(mydata)
print("===============================================================================================================")

# To get historical data for a specific indicator
mydata = te.getWBHistorical(series_code='usa.fr.inr.rinr', output_type='df')
print(mydata)
print("===============================================================================================================")

# To get your data into a csv file
df = pd.DataFrame(mydata)
path = r'worldBank.csv'
df.to_csv(path, index=False, header=True, sep='|')

# If you want the code into an html table format, you can use the example below in your html projects
# print(mydata.to_html())
# Out:
#                            Category
# 0                 Urban Development
# 1         Social Protection & Labor
# 2              Science & Technology
# 3                     Public Sector
# 4                    Private Sector
# 5                           Poverty
# 6                             Other
# 7                    Infrastructure
# 8                            Health
# 9                  Financial Sector
# 10                    External Debt
# 11                      Environment
# 12                  Energy & Mining
# 13                        Education
# 14                 Economy & Growth
# 15                      Development
# 16                     Demographics
# 17                   Climate Change
# 18                Aid Effectiveness
# 19  Agriculture & Rural Development
# ===============================================================================================================
#       Series_code                    Series_name      Category Sub_category  \
# 0  SP.POP.0509.FE  Population ages 05-09, female  Demographics        Other
# 1  SP.POP.0004.MA    Population ages 00-04, male  Demographics        Other
# 2  SP.POP.0004.FE  Population ages 00-04, female  Demographics        Other
#
#                      Title                             Long_definition  \
# 0  Female population 05-09  Female population between the ages 5 to 9.
# 1    Male population 00-04    Male population between the ages 0 to 4.
# 2  Female population 00-04  Female population between the ages 0 to 4.
#
#                              Short_definition  \
# 0  Female population between the ages 5 to 9.
# 1    Male population between the ages 0 to 4.
# 2  Female population between the ages 0 to 4.
#
#                                        Source  \
# 0  Health Nutrition and Population Statistics
# 1  Health Nutrition and Population Statistics
# 2  Health Nutrition and Population Statistics
#
#                                                  URL  \
# 0  /country-list/female-population-05-09-wb-data....
# 1   /country-list/male-population-00-04-wb-data.html
# 2  /country-list/female-population-00-04-wb-data....
#
#                                         Organization     Unit Verbose_unit  \
# 0  World Bank staff estimates using the World Ban...  Persons      Persons
# 1  World Bank staff estimates using the World Ban...  Persons      Persons
# 2  World Bank staff estimates using the World Ban...  Persons      Persons
#
#                Last_update
# 0  2022-11-05T06:35:17.197
# 1   2022-11-05T06:34:47.08
# 2  2022-11-05T06:34:43.067
# ===============================================================================================================
#                       symbol      last                 date  previous  \
# 0   ZMB.SE.ADT.1524.LT.FE.ZS  92.80000  2020-06-15T00:00:00  91.62819
# 1   ZAF.SE.ADT.1524.LT.FE.ZS  97.47523  2021-06-15T00:00:00  98.82957
# 2   WSM.SE.ADT.1524.LT.FE.ZS  99.40000  2021-06-15T00:00:00  99.27000
# 3   WLD.SE.ADT.1524.LT.FE.ZS  91.50802  2022-06-15T00:00:00  91.28884
# 4   VUT.SE.ADT.1524.LT.FE.ZS  97.20000  2021-06-15T00:00:00  96.59661
# ..                       ...       ...                  ...       ...
# 86  ARG.SE.ADT.1524.LT.FE.ZS  99.75765  2018-06-15T00:00:00  99.62893
# 87  ARE.SE.ADT.1524.LT.FE.ZS  99.56336  2022-06-15T00:00:00  99.58560
# 88  ALB.SE.ADT.1524.LT.FE.ZS  99.90000  2022-06-15T00:00:00  99.82000
# 89  AFG.SE.ADT.1524.LT.FE.ZS  41.59372  2021-06-15T00:00:00  56.25475
# 90  ABW.SE.ADT.1524.LT.FE.ZS  99.41000  2020-06-15T00:00:00  99.39000
#
#            previousDate               country   category  \
# 0   2018-06-15T00:00:00                Zambia  Education
# 1   2019-06-15T00:00:00          South Africa  Education
# 2   2019-06-15T00:00:00                 Samoa  Education
# 3   2021-06-15T00:00:00                 World  Education
# 4   2018-06-15T00:00:00               Vanuatu  Education
# ..                  ...                   ...        ...
# 86  2016-06-15T00:00:00             Argentina  Education
# 87  2021-06-15T00:00:00  United Arab Emirates  Education
# 88  2021-06-15T00:00:00               Albania  Education
# 89  2018-06-15T00:00:00           Afghanistan  Education
# 90  2018-06-15T00:00:00                 Aruba  Education
#
#                                           description frequency unit  \
# 0   Literacy rate, youth female (% of females ages...    yearly    %
# 1   Literacy rate, youth female (% of females ages...    yearly    %
# 2   Literacy rate, youth female (% of females ages...    yearly    %
# 3   Literacy rate, youth female (% of females ages...    yearly    %
# 4   Literacy rate, youth female (% of females ages...    yearly    %
# ..                                                ...       ...  ...
# 86  Literacy rate, youth female (% of females ages...    yearly    %
# 87  Literacy rate, youth female (% of females ages...    yearly    %
# 88  Literacy rate, youth female (% of females ages...    yearly    %
# 89  Literacy rate, youth female (% of females ages...    yearly    %
# 90  Literacy rate, youth female (% of females ages...    yearly    %
#
#                                                 title  \
# 0   Literacy rate, youth female (% of females ages...
# 1   Literacy rate, youth female (% of females ages...
# 2   Literacy rate, youth female (% of females ages...
# 3   Literacy rate, youth female (% of females ages...
# 4   Literacy rate, youth female (% of females ages...
# ..                                                ...
# 86  Literacy rate, youth female (% of females ages...
# 87  Literacy rate, youth female (% of females ages...
# 88  Literacy rate, youth female (% of females ages...
# 89  Literacy rate, youth female (% of females ages...
# 90  Literacy rate, youth female (% of females ages...
#
#                                                   URL               lastUpdate
# 0   /zambia/literacy-rate-youth-female-percent-of-...   2024-04-21T16:38:32.41
# 1   /south-africa/literacy-rate-youth-female-perce...   2024-04-21T16:35:17.46
# 2   /samoa/literacy-rate-youth-female-percent-of-f...  2024-04-21T16:29:03.693
# 3   /world/literacy-rate-youth-female-percent-of-f...  2024-04-21T16:27:03.077
# 4   /vanuatu/literacy-rate-youth-female-percent-of...  2024-04-21T16:25:17.577
# ..                                                ...                      ...
# 86  /argentina/literacy-rate-youth-female-percent-...  2024-04-21T08:21:47.973
# 87  /united-arab-emirates/literacy-rate-youth-fema...  2024-04-21T08:19:24.543
# 88  /albania/literacy-rate-youth-female-percent-of...  2024-04-21T08:15:03.587
# 89  /afghanistan/literacy-rate-youth-female-percen...  2024-04-21T08:10:23.727
# 90  /aruba/literacy-rate-youth-female-percent-of-f...      2024-04-21T08:08:03
#
# [91 rows x 13 columns]
# ===============================================================================================================
#                   symbol         last                 date     previous  \
# 0     PRT.AG.LND.AGRI.K2  39622.95500  2021-06-15T00:00:00  39542.55600
# 1     PRT.AG.CON.FERT.ZS    175.80018  2021-06-15T00:00:00    180.81803
# 2  PRT.AG.CON.FERT.PT.ZS    143.69798  2021-06-15T00:00:00    148.97485
#
#           previousDate   country                         category  \
# 0  2020-06-15T00:00:00  Portugal  Agriculture & Rural Development
# 1  2020-06-15T00:00:00  Portugal  Agriculture & Rural Development
# 2  2020-06-15T00:00:00  Portugal  Agriculture & Rural Development
#
#                                          description frequency    unit  \
# 0                         Agricultural land (sq. km)    yearly  sq. Km
# 1  Fertilizer consumption (kilograms per hectare ...    yearly      KG
# 2  Fertilizer consumption (% of fertilizer produc...    yearly       %
#
#                                                title  \
# 0                         Agricultural land (sq. km)
# 1  Fertilizer consumption (kilograms per hectare ...
# 2  Fertilizer consumption (% of fertilizer produc...
#
#                                                  URL               lastUpdate
# 0     /portugal/agricultural-land-sq-km-wb-data.html   2024-04-21T15:00:36.02
# 1  /portugal/fertilizer-consumption-kilograms-per...  2024-04-21T15:00:36.473
# 2  /portugal/fertilizer-consumption-percent-of-fe...  2024-04-21T15:00:36.513
# ===============================================================================================================
#             symbol     last                 date  previous  \
# 0  USA.FR.INR.RINR -1.18936  2021-06-15T00:00:00   2.21041
#
#           previousDate        country          category  \
# 0  2020-06-15T00:00:00  United States  Financial Sector
#
#               description frequency unit               title  \
# 0  Real interest rate (%)    yearly    %  Real interest rate
#
#                                                  URL               lastUpdate
# 0  /united-states/real-interest-rate-percent-wb-d...  2024-04-21T16:11:03.557
# ===============================================================================================================
#             symbol                 date    value
# 0  usa.fr.inr.rinr  1963-06-15T00:00:00  3.37488
# 1  usa.fr.inr.rinr  1962-06-15T00:00:00  3.21535
# 2  usa.fr.inr.rinr  1961-06-15T00:00:00  3.10788
# ===============================================================================================================
