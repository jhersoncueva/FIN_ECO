# %%
import yfinance as yf
import pandas as pd
import datetime as dt

# %%
start = dt.datetime(2020, 1, 1)
end = dt.datetime.now()

sp500 = yf.download('^GSPC', start=start, end=end)[['Close']]  # S&P 500
nasdaq = yf.download('^IXIC', start=start, end=end)[['Close']]  # Nasdaq Composite
dowjones = yf.download('^DJI', start=start, end=end)[['Close']]  # Dow Jones Industrial Average
russell2000 = yf.download('^RUT', start=start, end=end)[['Close']]  # Russell 2000

sp500.rename(columns={'Close': 'S&P 500'}, inplace=True)
nasdaq.rename(columns={'Close': 'Nasdaq'}, inplace=True)
dowjones.rename(columns={'Close': 'Dow Jones'}, inplace=True)
russell2000.rename(columns={'Close': 'Russell 2000'}, inplace=True)

# indices_data = pd.concat([sp500, nasdaq, dowjones, russell2000], axis=1)

# indices_data.to_excel("indices_data_US.xlsx",sheet_name="indices_data_US")
# indices_data

indices_data = pd.concat([sp500, nasdaq, dowjones, russell2000], axis=1)

# Normalizar los datos a 100 tomando el valor del primer día
indices_data = indices_data / indices_data.iloc[0] * 100

# Guardar el DataFrame en Excel
indices_data.to_excel("indices_data_US.xlsx", sheet_name="indices_data_US")

# Mostrar los primeros datos normalizados
indices_data.head()
# Out:
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Local\Temp\ipykernel_29328\3427639233.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   russell2000.rename(columns={'Close': 'Russell 2000'}, inplace=True)
# C:\Users\HP SUPPORT\AppData\Local\Temp\ipykernel_29328\3427639233.py:25: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   indices_data.to_excel("indices_data_US.xlsx", sheet_name="indices_data_US")
#                S&P 500      Nasdaq   Dow Jones  Russell 2000
# Date
# 2020-01-02  100.000000  100.000000  100.000000    100.000000
# 2020-01-03   99.294013   99.214481   99.189714     99.646020
# 2020-01-06   99.644856   99.772104   99.426994     99.789412
# 2020-01-07   99.365527   99.740323   99.012356     99.492434
# 2020-01-08   99.852662  100.407490   99.571472     99.809209

# %%
import yfinance as yf
import pandas as pd
import datetime as dt

# Fechas de inicio y fin
start = dt.datetime(2020, 1, 7)
end = dt.datetime.now()

#US
sp500 = yf.download('^GSPC', start=start, end=end)[['Close']]  # S&P 500
nasdaq = yf.download('^IXIC', start=start, end=end)[['Close']]  # Nasdaq Composite
dowjones = yf.download('^DJI', start=start, end=end)[['Close']]  # Dow Jones Industrial Average
russell2000 = yf.download('^RUT', start=start, end=end)[['Close']]  # Russell 2000

sp500.rename(columns={'Close': 'S&P 500'}, inplace=True)
nasdaq.rename(columns={'Close': 'Nasdaq'}, inplace=True)
dowjones.rename(columns={'Close': 'Dow Jones'}, inplace=True)
russell2000.rename(columns={'Close': 'Russell 2000'}, inplace=True)


# Europa
ftse = yf.download('^FTSE', start=start, end=end)[['Close']]
dax = yf.download('^GDAXI', start=start, end=end)[['Close']]
cac = yf.download('^FCHI', start=start, end=end)[['Close']]
stoxx = yf.download('^STOXX50E', start=start, end=end)[['Close']]


ftse.rename(columns={'Close': 'FTSE 100'}, inplace=True)
dax.rename(columns={'Close': 'DAX'}, inplace=True)
cac.rename(columns={'Close': 'CAC 40'}, inplace=True)
stoxx.rename(columns={'Close': 'Euro Stoxx 50'}, inplace=True)

# Asia
nikkei = yf.download('^N225', start=start, end=end)[['Close']]
hangseng = yf.download('^HSI', start=start, end=end)[['Close']]
shanghai = yf.download('000001.SS', start=start, end=end)[['Close']]
kospi = yf.download('^KS11', start=start, end=end)[['Close']]

nikkei.rename(columns={'Close': 'Nikkei 225'}, inplace=True)
hangseng.rename(columns={'Close': 'Hang Seng'}, inplace=True)
shanghai.rename(columns={'Close': 'Shanghai Composite'}, inplace=True)
kospi.rename(columns={'Close': 'Kospi'}, inplace=True)

# Latinoamérica
bovespa = yf.download('^BVSP', start=start, end=end)[['Close']]
ipc_mexico = yf.download('^MXX', start=start, end=end)[['Close']]
merval = yf.download('^MERV', start=start, end=end)[['Close']]

bovespa.rename(columns={'Close': 'Bovespa'}, inplace=True)
ipc_mexico.rename(columns={'Close': 'IPC México'}, inplace=True)
merval.rename(columns={'Close': 'Merval'}, inplace=True)


#Perú
sp_bvl = yf.download('^SPBLPGPT', start=start, end=end)[['Close']]
sp_bvl.rename(columns={'Close': 'S&P/BVL General'}, inplace=True)

EPU = yf.download('EPU', start=start, end=end)[['Close']]
EPU.rename(columns={'Close': 'MSCI Peru ETF'}, inplace=True)

# Concatenar todos los índices en un DataFrame
indices_data = pd.concat([sp500, nasdaq, dowjones, russell2000,ftse, dax, cac, stoxx, nikkei, hangseng, shanghai, kospi, bovespa, ipc_mexico, merval,sp_bvl,EPU], axis=1)
# indices_data = pd.concat([indices_data, sp_bvl], axis=1)

# Normalizar los datos a 100 tomando el valor del primer día
indices_data = indices_data / indices_data.iloc[0] * 100

indices_data.to_excel("indices_data_US.xlsx", sheet_name="indices_data_US")
# Mostrar las primeras filas del DataFrame
indices_data.head()
# Out:
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Local\Temp\ipykernel_29328\3397308787.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   russell2000.rename(columns={'Close': 'Russell 2000'}, inplace=True)
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Local\Temp\ipykernel_29328\3397308787.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stoxx.rename(columns={'Close': 'Euro Stoxx 50'}, inplace=True)
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Local\Temp\ipykernel_29328\3397308787.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kospi.rename(columns={'Close': 'Kospi'}, inplace=True)
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Local\Temp\ipykernel_29328\3397308787.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merval.rename(columns={'Close': 'Merval'}, inplace=True)
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\HP SUPPORT\AppData\Local\Temp\ipykernel_29328\3397308787.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp_bvl.rename(columns={'Close': 'S&P/BVL General'}, inplace=True)
# C:\Users\HP SUPPORT\AppData\Local\Temp\ipykernel_29328\3397308787.py:65: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   indices_data.to_excel("indices_data_US.xlsx", sheet_name="indices_data_US")
#                S&P 500      Nasdaq   Dow Jones  Russell 2000    FTSE 100  \
# Date
# 2020-01-07  100.000000  100.000000  100.000000    100.000000  100.000000
# 2020-01-08  100.490245  100.668905  100.564693    100.318391  100.013203
# 2020-01-09  101.159034  101.486998  101.305713    100.402816  100.319521
# 2020-01-10  100.870207  101.216070  100.839954     99.959595  100.184845
# 2020-01-13  101.573899  102.264408  101.131314    100.681412  100.576984
#
#                    DAX      CAC 40  Euro Stoxx 50  Nikkei 225   Hang Seng  \
# Date
# 2020-01-07  100.000000  100.000000     100.000000  100.000000  100.000000
# 2020-01-08  100.705759  100.310193     100.354062   98.426513   99.173292
# 2020-01-09  102.027920  100.502295     100.974393  100.696261  100.843651
# 2020-01-10  101.939085  100.411815     100.805214  101.165816  101.116228
# 2020-01-13  101.698740  100.395686     100.543458         NaN  102.234579
#
#             Shanghai Composite       Kospi     Bovespa  IPC México  \
# Date
# 2020-01-07          100.000000  100.000000  100.000000  100.000000
# 2020-01-08           98.779022   98.886254   99.644271  100.709051
# 2020-01-09           99.680497  100.501481   99.387118  100.938369
# 2020-01-10           99.597044  101.418032   99.006532  101.138008
# 2020-01-13          100.346820  102.469271  100.568308  101.561808
#
#                 Merval  S&P/BVL General
# Date
# 2020-01-07  100.000000       100.000000
# 2020-01-08   99.756786        99.544039
# 2020-01-09  102.237572        99.730849
# 2020-01-10  103.949801        99.863593
# 2020-01-13  102.193793       100.003129

# %%
start = dt.datetime(2020, 1, 7)
end = dt.datetime.now()
yf.download('^GSPC', start=start, end=end)[['Close']]
# Out:
# C:\Users\HP SUPPORT\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
#                   Close
# Date
# 2020-01-07  3237.179932
# 2020-01-08  3253.050049
# 2020-01-09  3274.699951
# 2020-01-10  3265.350098
# 2020-01-13  3288.129883
# ...                 ...
# 2024-09-16  5633.089844
# 2024-09-17  5634.580078
# 2024-09-18  5618.259766
# 2024-09-19  5713.640137
# 2024-09-20  5702.549805
#
# [1185 rows x 1 columns]

# %%
import pandas as pd
df = pd.read_excel("C:/Users/HP SUPPORT/documents/GitHub/FINANCE_ECONOMICA/scrapping/Stock Data Yahoo/SPY.xlsx")
df
# Out:
#           Date    Adj Close
# 0   2020-01-02  3257.850098
# 1   2020-01-03  3234.850098
# 2   2020-01-06  3246.280029
# 3   2020-01-07  3237.179932
# 4   2020-01-08  3253.050049
# ..         ...          ...
# 500 2021-12-27  4791.189941
# 501 2021-12-28  4786.350098
# 502 2021-12-29  4793.060059
# 503 2021-12-30  4778.729980
# 504 2021-12-31  4766.180176
#
# [505 rows x 2 columns]

# %%
import datetime as dt
import pandas_datareader.data as web

# Fechas de inicio y final
start = dt.datetime(2000, 2, 28)
end = dt.datetime.now()

# Descargar datos de las tasas de los bonos del Tesoro
data = web.DataReader('DGS10', 'fred', start, end)
data["DGS2"] = web.DataReader('DGS2', 'fred', start, end)

# Descargar otros indicadores económicos
data["FEDFUNDS"] = web.DataReader('FEDFUNDS', 'fred', start, end)  # Tasa efectiva de fondos federales
data["CPI"] = web.DataReader('CPIAUCSL', 'fred', start, end)  # Índice de precios al consumidor (CPI)
data["Unemployment"] = web.DataReader('UNRATE', 'fred', start, end)  # Tasa de desempleo


data["var_CPI"] = pd.DataFrame(data["CPI"].pct_change(12)*1000)

# Limpiar los datos, eliminando filas con valores nulos
data = data.dropna()

# DATA["FEDFUNDS"].las() = 5.00

data.to_excel("data_US.xlsx",sheet_name="data_US")

data
# Out:
# C:\Users\HP SUPPORT\AppData\Local\Temp\ipykernel_29328\2060712965.py:18: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   data["var_CPI"] = pd.DataFrame(data["CPI"].pct_change(12)*1000)
# C:\Users\HP SUPPORT\AppData\Local\Temp\ipykernel_29328\2060712965.py:25: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   data.to_excel("data_US.xlsx",sheet_name="data_US")
#             DGS10  DGS2  FEDFUNDS      CPI  Unemployment   var_CPI
# DATE
# 2000-05-01   6.29  6.73      6.27  171.200           4.0  1.169591
# 2000-06-01   6.20  6.61      6.53  172.200           4.0  5.841121
# 2000-08-01   6.00  6.27      6.50  172.700           4.1  2.903600
# 2000-09-01   5.68  6.09      6.52  173.600           3.9  5.211349
# 2000-11-01   5.74  5.88      6.51  174.200           3.9  3.456221
# ...           ...   ...       ...      ...           ...       ...
# 2024-03-01   4.19  4.54      5.33  312.230           3.8  3.780694
# 2024-04-01   4.33  4.72      5.33  313.207           3.9  3.129104
# 2024-05-01   4.63  4.96      5.33  313.225           4.0  0.057470
# 2024-07-01   4.48  4.77      5.33  313.534           4.3  0.986511
# 2024-08-01   3.99  4.16      5.33  314.121           4.2  1.872205
#
# [190 rows x 6 columns]

# %%
data["var_CPI"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>
